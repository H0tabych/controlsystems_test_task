# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Загрузка данных

# %%
fname = "real_estate_data.csv"
df = pd.read_csv(fname, sep="\s+")

# %% [markdown]
# # Вывести первые 10 записей (и общее число) о квартирах с высотой потолков (ceiling_height) выше 2.8м

# %%
more_28_ch = df[df.ceiling_height > 2.8]

# %%
more_28_ch.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 1              7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2             10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3              0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4              2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6              6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7              5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 11             9   3300000.0       44.00  2018-08-27T00:00:00      2
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
#
#     ceiling_height floors_total living_area  floor is_apartment  ...  \
# 1            11.00         18.6           1  False        False  ...
# ...

# %%
more_28_ch.shape
# Out:
# (12084, 22)

# %% [markdown]
# # Уменьшить на порядок значения высоты потолков для значений, превышающих 20м

# %%
df.loc[df.ceiling_height > 20, "ceiling_height"] = df[df.ceiling_height > 20].ceiling_height.div(10)

# %%
df.ceiling_height.describe()
# Out:
# count    23699.000000
# mean         4.822614
# std          4.128088
# min          1.000000
# 25%          2.550000
# 50%          2.760000
# 75%          5.000000
# max         20.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# ## Составить таблицу вида: вниз - кол-во комнат, вправо - минимальная, максимальная и медианная площадь

# %%
df.pivot_table(index="rooms", values="total_area", aggfunc=[np.min, np.max, np.median])
# Out:
#             amin       amax     median
#       total_area total_area total_area
# rooms
# 0           15.5      371.0      26.05
# 1           12.0      494.1      36.56
# 2           20.0      196.0      53.00
# 3           40.1      363.1      73.00
# 4           42.0      500.0      99.30
# 5           40.0      507.0     146.45
# 6           87.0      500.0     184.30
# 7          100.6      631.2     214.00
# 8          150.0      373.1     235.70
# 9          235.0      400.0     300.95
# 10         216.1      290.0     272.60
# 11         183.7      194.1     188.90
# 12         900.0      900.0     900.00
# 14         245.4      363.0     304.20
# 15         590.0      590.0     590.00
# 16         270.0      270.0     270.00
# 19         374.6      374.6     374.60

# %% [markdown]
# ## Вставить медианное значение высоты для пустых значений высот потолка (с разбивкой по городам)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  object
#  7   living_area           23699 non-null  object
#  8   floor                 23699 non-null  object
#  9   is_apartment          23698 non-null  object
#  10  studio                23687 non-null  object
#  11  open_plan             23548 non-null  object
#  12  kitchen_area          23184 non-null  object
#  13  balcony               22399 non-null  object
#  14  locality_name         20919 non-null  object
# ...

# %%
df.shape
# Out:
# (23699, 22)

# %% [markdown]
# В значениях высоты потолка отсутствуют пропуски
